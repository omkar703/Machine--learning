# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split    

# Load the dataset
df = pd.DataFrame([[2600, 550000], [3000, 565000], [3200, 610000], [3600, 680000], [4000, 725000]], columns=['Area', 'Price'])
print(df)
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df['Area'], df['Price'])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(df[['Area']], df['Price'])


# Plotting the regression line
plt.scatter(df['Area'], df['Price'])
plt.plot(df['Area'], model.predict(df[['Area']]), color='red')
# Out:
# [628715.75342466]
# c:\Users\omkar\anaconda3\envs\ml_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# Predicting a new value
print(model.predict([[3300]]))
# Out:
# [628715.75342466]
# c:\Users\omkar\anaconda3\envs\ml_env\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# np.float64(180616.43835616432)
